# %%
import numpy as np
import pandas as pd
from datetime import datetime
import gc
import warnings
from bayes_opt import BayesianOptimization

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from sklearn.model_selection import KFold
import warnings
import time
import sys
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error
from datetime import datetime
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod(
            (datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Time taken: %i hours %i minutes and %s seconds.' % (thour, tmin, round(tsec, 2)))

# %%
def reduce_mem_usage(df):
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
train = pd.read_csv("data/train.csv", index_col=0)
train = reduce_mem_usage(train)

target = train['target']
del train['target']
# Out:
# Mem. usage decreased to  4.04 Mb (56.2% reduction)

# %%
unimportant_features = [
    'auth_category_2_1.0_mean',
    'auth_category_2_2.0_mean',
    'auth_category_2_3.0_mean',
    'auth_category_2_5.0_mean',
    'hist_category_2_3.0_mean',
    'hist_category_2_4.0_mean',
    'hist_category_2_5.0_mean',
    'hist_category_3_A_mean',
    'hist_installments_min',
    'hist_installments_std',
    'hist_month_lag_std',
    'hist_purchase_amount_max',
    'hist_purchase_month_max',
    'hist_purchase_month_min',
    'hist_purchase_month_std',
    'installments_min_mean',
    'new_category_2_1.0_mean',
    'new_category_2_2.0_mean',
    'new_category_2_3.0_mean',
    'new_category_2_5.0_mean',
    'new_city_id_nunique',
    'new_installments_std',
    'new_state_id_nunique',
    'purchase_amount_mean_mean'
]
features = [c for c in train.columns if c not in ['card_id', 'first_active_month']]
#features = [f for f in features if f not in unimportant_features]
categorical_feats = [c for c in features if 'feature_' in c]

# %%
def LGB_CV(
          max_depth,
          num_leaves,
          min_data_in_leaf,
          feature_fraction,
          bagging_fraction,
          lambda_l1
         ):
    
    folds = KFold(n_splits=10, shuffle=True, random_state=15)
    oof = np.zeros(train.shape[0])

    for fold_, (trn_idx, val_idx) in enumerate(folds.split(train.values, target.values)):
        print("fold n°{}".format(fold_))
        trn_data = lgb.Dataset(train.iloc[trn_idx][features],
                               label=target.iloc[trn_idx],
                               categorical_feature=categorical_feats)
        val_data = lgb.Dataset(train.iloc[val_idx][features],
                               label=target.iloc[val_idx],
                               categorical_feature=categorical_feats)
    
        param = {
            'num_leaves': int(num_leaves),
            'min_data_in_leaf': int(min_data_in_leaf), 
            'objective':'regression',
            'max_depth': int(max_depth),
            'learning_rate': 0.01,
            "boosting": "gbdt",
            "feature_fraction": feature_fraction,
            "bagging_freq": 1,
            "bagging_fraction": bagging_fraction ,
            "bagging_seed": 11,
            "metric": 'rmse',
            "lambda_l1": lambda_l1,
            "verbosity": -1
        }
    
        clf = lgb.train(param,
                        trn_data,
                        10000,
                        valid_sets = [trn_data, val_data],
                        verbose_eval=500,
                        early_stopping_rounds = 500)
        
        oof[val_idx] = clf.predict(train.iloc[val_idx][features],
                                   num_iteration=clf.best_iteration)
        
        del clf, trn_idx, val_idx
        gc.collect()
        
    return -mean_squared_error(oof, target)**0.5

# %%
LGB_BO = BayesianOptimization(LGB_CV, {
    'max_depth': (1, 20),
    'num_leaves': (2, 200),
    'min_data_in_leaf': (1, 200),
    'feature_fraction': (0.2, 1.0),
    'bagging_fraction': (0.2, 1.0),
    'lambda_l1': (0, 6)
    })

# %%
print('-'*126)

start_time = timer(None)
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    LGB_BO.maximize(init_points=2, n_iter=20, acq='ei', xi=0.0)
timer(start_time)


print('-'*130)
print('Final Results')
print('Maximum  value: %f' % LGB_BO.max['target'])
print('Best  parameters: ', LGB_BO.max['params'])


history_df = pd.DataFrame([x['params'] for x in LGB_BO.res])
history_df2 = pd.DataFrame([x['target'] for x in LGB_BO.res])
history_df = pd.concat((history_df, history_df2), axis=1)
history_df.rename(columns = { 0 : 'gini'}, inplace=True)
history_df.to_csv('ParametersOptimization.csv')
# Out:
# ------------------------------------------------------------------------------------------------------------------------------
# |   iter    |  target   | baggin... | featur... | lambda_l1 | max_depth | min_da... | num_le... |
# -------------------------------------------------------------------------------------------------
# fold n°0
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84075	valid_1's rmse: 3.9206
# [1000]	training's rmse: 3.84073	valid_1's rmse: 3.92051
# [1500]	training's rmse: 3.84073	valid_1's rmse: 3.9205
# Early stopping, best iteration is:
# [1018]	training's rmse: 3.84073	valid_1's rmse: 3.9205
# fold n°1
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84943	valid_1's rmse: 3.84312
# Early stopping, best iteration is:
# [272]	training's rmse: 3.84954	valid_1's rmse: 3.84307
# fold n°2
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85707	valid_1's rmse: 3.77361
# [1000]	training's rmse: 3.85705	valid_1's rmse: 3.77356
# [1500]	training's rmse: 3.85705	valid_1's rmse: 3.77358
# Early stopping, best iteration is:
# [1030]	training's rmse: 3.85705	valid_1's rmse: 3.77356
# fold n°3
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85044	valid_1's rmse: 3.83392
# Early stopping, best iteration is:
# [368]	training's rmse: 3.85048	valid_1's rmse: 3.83391
# fold n°4
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.86771	valid_1's rmse: 3.67417
# Early stopping, best iteration is:
# [312]	training's rmse: 3.86778	valid_1's rmse: 3.67412
# fold n°5
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8453	valid_1's rmse: 3.88028
# [1000]	training's rmse: 3.84529	valid_1's rmse: 3.88017
# [1500]	training's rmse: 3.84529	valid_1's rmse: 3.88015
# [2000]	training's rmse: 3.84529	valid_1's rmse: 3.88016
# Early stopping, best iteration is:
# [1715]	training's rmse: 3.84529	valid_1's rmse: 3.88012
# fold n°6
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.82867	valid_1's rmse: 4.02544
# Early stopping, best iteration is:
# [102]	training's rmse: 3.8293	valid_1's rmse: 4.02501
# fold n°7
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.83809	valid_1's rmse: 3.94394
# [1000]	training's rmse: 3.83808	valid_1's rmse: 3.94387
# [1500]	training's rmse: 3.83808	valid_1's rmse: 3.94386
# Early stopping, best iteration is:
# [1055]	training's rmse: 3.83808	valid_1's rmse: 3.94386
# fold n°8
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85086	valid_1's rmse: 3.83014
# Early stopping, best iteration is:
# [458]	training's rmse: 3.85087	valid_1's rmse: 3.83013
# fold n°9
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85922	valid_1's rmse: 3.75366
# Early stopping, best iteration is:
# [209]	training's rmse: 3.85944	valid_1's rmse: 3.75352
# |  1        | -3.849    |  0.7607   |  0.9528   |  1.703    |  5.208    |  56.49    |  13.31    |
# fold n°0
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84131	valid_1's rmse: 3.92186
# [1000]	training's rmse: 3.84124	valid_1's rmse: 3.9218
# [1500]	training's rmse: 3.84123	valid_1's rmse: 3.92181
# Early stopping, best iteration is:
# [1229]	training's rmse: 3.84123	valid_1's rmse: 3.92178
# fold n°1
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85017	valid_1's rmse: 3.84308
# [1000]	training's rmse: 3.8501	valid_1's rmse: 3.84291
# [1500]	training's rmse: 3.85009	valid_1's rmse: 3.84288
# Early stopping, best iteration is:
# [1341]	training's rmse: 3.85009	valid_1's rmse: 3.84286
# fold n°2
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85765	valid_1's rmse: 3.77476
# [1000]	training's rmse: 3.85757	valid_1's rmse: 3.77476
# Early stopping, best iteration is:
# [672]	training's rmse: 3.8576	valid_1's rmse: 3.77473
# fold n°3
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85115	valid_1's rmse: 3.83411
# [1000]	training's rmse: 3.85107	valid_1's rmse: 3.83405
# [1500]	training's rmse: 3.85106	valid_1's rmse: 3.83405
# Early stopping, best iteration is:
# [1389]	training's rmse: 3.85106	valid_1's rmse: 3.83404
# fold n°4
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8684	valid_1's rmse: 3.67453
# [1000]	training's rmse: 3.86832	valid_1's rmse: 3.67451
# Early stopping, best iteration is:
# [880]	training's rmse: 3.86833	valid_1's rmse: 3.67448
# fold n°5
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84591	valid_1's rmse: 3.88129
# [1000]	training's rmse: 3.84582	valid_1's rmse: 3.88122
# [1500]	training's rmse: 3.84581	valid_1's rmse: 3.88119
# [2000]	training's rmse: 3.84581	valid_1's rmse: 3.88117
# [2500]	training's rmse: 3.84581	valid_1's rmse: 3.88118
# Early stopping, best iteration is:
# [2102]	training's rmse: 3.84581	valid_1's rmse: 3.88118
# fold n°6
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.82939	valid_1's rmse: 4.02528
# Early stopping, best iteration is:
# [171]	training's rmse: 3.82978	valid_1's rmse: 4.02516
# fold n°7
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.83871	valid_1's rmse: 3.94495
# [1000]	training's rmse: 3.83864	valid_1's rmse: 3.94474
# [1500]	training's rmse: 3.83864	valid_1's rmse: 3.94466
# [2000]	training's rmse: 3.83864	valid_1's rmse: 3.94464
# [2500]	training's rmse: 3.83864	valid_1's rmse: 3.94461
# Early stopping, best iteration is:
# [2477]	training's rmse: 3.83864	valid_1's rmse: 3.9446
# fold n°8
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85157	valid_1's rmse: 3.83044
# [1000]	training's rmse: 3.8515	valid_1's rmse: 3.83029
# [1500]	training's rmse: 3.85149	valid_1's rmse: 3.83022
# [2000]	training's rmse: 3.85149	valid_1's rmse: 3.83026
# Early stopping, best iteration is:
# [1715]	training's rmse: 3.85149	valid_1's rmse: 3.83022
# fold n°9
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85997	valid_1's rmse: 3.75351
# [1000]	training's rmse: 3.85988	valid_1's rmse: 3.75348
# Early stopping, best iteration is:
# [759]	training's rmse: 3.8599	valid_1's rmse: 3.75346
# |  2        | -3.849    |  0.4547   |  0.5869   |  4.691    |  14.85    |  153.3    |  142.3    |
# fold n°0
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84131	valid_1's rmse: 3.92185
# [1000]	training's rmse: 3.84124	valid_1's rmse: 3.92179
# [1500]	training's rmse: 3.84123	valid_1's rmse: 3.92178
# Early stopping, best iteration is:
# [1140]	training's rmse: 3.84123	valid_1's rmse: 3.92178
# fold n°1
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85016	valid_1's rmse: 3.84306
# [1000]	training's rmse: 3.8501	valid_1's rmse: 3.84292
# [1500]	training's rmse: 3.85009	valid_1's rmse: 3.84289
# [2000]	training's rmse: 3.85009	valid_1's rmse: 3.84287
# [2500]	training's rmse: 3.85009	valid_1's rmse: 3.84287
# Early stopping, best iteration is:
# [2203]	training's rmse: 3.85009	valid_1's rmse: 3.84285
# fold n°2
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85765	valid_1's rmse: 3.77476
# [1000]	training's rmse: 3.85757	valid_1's rmse: 3.77475
# Early stopping, best iteration is:
# [735]	training's rmse: 3.85759	valid_1's rmse: 3.77474
# fold n°3
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85114	valid_1's rmse: 3.83411
# [1000]	training's rmse: 3.85107	valid_1's rmse: 3.83403
# Early stopping, best iteration is:
# [960]	training's rmse: 3.85107	valid_1's rmse: 3.83402
# fold n°4
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8684	valid_1's rmse: 3.6745
# [1000]	training's rmse: 3.86832	valid_1's rmse: 3.67449
# Early stopping, best iteration is:
# [884]	training's rmse: 3.86832	valid_1's rmse: 3.67447
# fold n°5
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8459	valid_1's rmse: 3.88128
# [1000]	training's rmse: 3.84582	valid_1's rmse: 3.8812
# [1500]	training's rmse: 3.84581	valid_1's rmse: 3.88118
# Early stopping, best iteration is:
# [1202]	training's rmse: 3.84581	valid_1's rmse: 3.88118
# fold n°6
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8294	valid_1's rmse: 4.02527
# Early stopping, best iteration is:
# [177]	training's rmse: 3.82975	valid_1's rmse: 4.02517
# fold n°7
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8387	valid_1's rmse: 3.94494
# [1000]	training's rmse: 3.83864	valid_1's rmse: 3.94471
# [1500]	training's rmse: 3.83864	valid_1's rmse: 3.94464
# [2000]	training's rmse: 3.83864	valid_1's rmse: 3.94463
# Early stopping, best iteration is:
# [1634]	training's rmse: 3.83864	valid_1's rmse: 3.94462
# fold n°8
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85158	valid_1's rmse: 3.83045
# [1000]	training's rmse: 3.8515	valid_1's rmse: 3.83029
# [1500]	training's rmse: 3.85149	valid_1's rmse: 3.83023
# Early stopping, best iteration is:
# [1486]	training's rmse: 3.85149	valid_1's rmse: 3.83022
# fold n°9
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85996	valid_1's rmse: 3.75351
# [1000]	training's rmse: 3.85988	valid_1's rmse: 3.75347
# Early stopping, best iteration is:
# [796]	training's rmse: 3.8599	valid_1's rmse: 3.75346
# |  3        | -3.849    |  0.559    |  0.3763   |  3.71     |  10.89    |  1.088    |  199.0    |
# fold n°0
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84127	valid_1's rmse: 3.92179
# [1000]	training's rmse: 3.84123	valid_1's rmse: 3.92179
# Early stopping, best iteration is:
# [731]	training's rmse: 3.84124	valid_1's rmse: 3.92177
# fold n°1
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85012	valid_1's rmse: 3.84298
# [1000]	training's rmse: 3.85009	valid_1's rmse: 3.84288
# [1500]	training's rmse: 3.85009	valid_1's rmse: 3.84288
# [2000]	training's rmse: 3.85009	valid_1's rmse: 3.84287
# [2500]	training's rmse: 3.85009	valid_1's rmse: 3.84286
# Early stopping, best iteration is:
# [2395]	training's rmse: 3.85009	valid_1's rmse: 3.84286
# fold n°2
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8576	valid_1's rmse: 3.77474
# Early stopping, best iteration is:
# [349]	training's rmse: 3.85767	valid_1's rmse: 3.77473
# fold n°3
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85109	valid_1's rmse: 3.83409
# [1000]	training's rmse: 3.85106	valid_1's rmse: 3.83403
# [1500]	training's rmse: 3.85106	valid_1's rmse: 3.83404
# Early stopping, best iteration is:
# [1219]	training's rmse: 3.85106	valid_1's rmse: 3.83403
# fold n°4
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.86834	valid_1's rmse: 3.67454
# [1000]	training's rmse: 3.86831	valid_1's rmse: 3.67453
# [1500]	training's rmse: 3.86831	valid_1's rmse: 3.67453
# Early stopping, best iteration is:
# [1230]	training's rmse: 3.86831	valid_1's rmse: 3.6745
# fold n°5
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84586	valid_1's rmse: 3.88118
# [1000]	training's rmse: 3.84581	valid_1's rmse: 3.88118
# Early stopping, best iteration is:
# [643]	training's rmse: 3.84583	valid_1's rmse: 3.88115
# fold n°6
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.82935	valid_1's rmse: 4.02532
# Early stopping, best iteration is:
# [188]	training's rmse: 3.82965	valid_1's rmse: 4.02519
# fold n°7
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.83867	valid_1's rmse: 3.94479
# [1000]	training's rmse: 3.83864	valid_1's rmse: 3.94465
# [1500]	training's rmse: 3.83864	valid_1's rmse: 3.94463
# [2000]	training's rmse: 3.83864	valid_1's rmse: 3.94462
# Early stopping, best iteration is:
# [1642]	training's rmse: 3.83864	valid_1's rmse: 3.94463
# fold n°8
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85153	valid_1's rmse: 3.83039
# [1000]	training's rmse: 3.85149	valid_1's rmse: 3.83026
# [1500]	training's rmse: 3.85149	valid_1's rmse: 3.83022
# [2000]	training's rmse: 3.85149	valid_1's rmse: 3.83024
# Early stopping, best iteration is:
# [1608]	training's rmse: 3.85149	valid_1's rmse: 3.83022
# fold n°9
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85991	valid_1's rmse: 3.75349
# [1000]	training's rmse: 3.85987	valid_1's rmse: 3.75347
# Early stopping, best iteration is:
# [967]	training's rmse: 3.85987	valid_1's rmse: 3.75347
# |  4        | -3.849    |  0.6402   |  0.7669   |  3.087    |  1.319    |  197.8    |  2.115    |
# fold n°0
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84127	valid_1's rmse: 3.92179
# [1000]	training's rmse: 3.84123	valid_1's rmse: 3.92179
# Early stopping, best iteration is:
# [731]	training's rmse: 3.84124	valid_1's rmse: 3.92177
# fold n°1
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85012	valid_1's rmse: 3.84297
# [1000]	training's rmse: 3.85009	valid_1's rmse: 3.84288
# [1500]	training's rmse: 3.85009	valid_1's rmse: 3.84287
# [2000]	training's rmse: 3.85009	valid_1's rmse: 3.84286
# Early stopping, best iteration is:
# [1692]	training's rmse: 3.85009	valid_1's rmse: 3.84285
# fold n°2
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85761	valid_1's rmse: 3.77474
# Early stopping, best iteration is:
# [414]	training's rmse: 3.85764	valid_1's rmse: 3.77473
# fold n°3
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8511	valid_1's rmse: 3.8341
# [1000]	training's rmse: 3.85106	valid_1's rmse: 3.83404
# Early stopping, best iteration is:
# [930]	training's rmse: 3.85106	valid_1's rmse: 3.83403
# fold n°4
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.86835	valid_1's rmse: 3.67456
# [1000]	training's rmse: 3.86831	valid_1's rmse: 3.67452
# Early stopping, best iteration is:
# [950]	training's rmse: 3.86831	valid_1's rmse: 3.67451
# fold n°5
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84586	valid_1's rmse: 3.88117
# [1000]	training's rmse: 3.84581	valid_1's rmse: 3.88118
# Early stopping, best iteration is:
# [679]	training's rmse: 3.84583	valid_1's rmse: 3.88115
# fold n°6
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.82935	valid_1's rmse: 4.02533
# Early stopping, best iteration is:
# [190]	training's rmse: 3.82964	valid_1's rmse: 4.0252
# fold n°7
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.83868	valid_1's rmse: 3.94481
# [1000]	training's rmse: 3.83864	valid_1's rmse: 3.94466
# [1500]	training's rmse: 3.83864	valid_1's rmse: 3.94462
# [2000]	training's rmse: 3.83864	valid_1's rmse: 3.94463
# Early stopping, best iteration is:
# [1524]	training's rmse: 3.83864	valid_1's rmse: 3.94462
# fold n°8
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85153	valid_1's rmse: 3.83039
# [1000]	training's rmse: 3.85149	valid_1's rmse: 3.83026
# [1500]	training's rmse: 3.85149	valid_1's rmse: 3.83022
# Early stopping, best iteration is:
# [1442]	training's rmse: 3.85149	valid_1's rmse: 3.83021
# fold n°9
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85991	valid_1's rmse: 3.7535
# [1000]	training's rmse: 3.85988	valid_1's rmse: 3.75348
# [1500]	training's rmse: 3.85987	valid_1's rmse: 3.75349
# [2000]	training's rmse: 3.85987	valid_1's rmse: 3.75347
# Early stopping, best iteration is:
# [1829]	training's rmse: 3.85987	valid_1's rmse: 3.75346
# |  5        | -3.849    |  0.7126   |  0.9497   |  2.119    |  16.13    |  2.465    |  2.974    |
# fold n°0
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84075	valid_1's rmse: 3.9206
# [1000]	training's rmse: 3.84074	valid_1's rmse: 3.92053
# [1500]	training's rmse: 3.84074	valid_1's rmse: 3.92049
# [2000]	training's rmse: 3.84073	valid_1's rmse: 3.92053
# Early stopping, best iteration is:
# [1680]	training's rmse: 3.84074	valid_1's rmse: 3.92046
# fold n°1
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84943	valid_1's rmse: 3.84311
# Early stopping, best iteration is:
# [272]	training's rmse: 3.84955	valid_1's rmse: 3.84306
# fold n°2
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85707	valid_1's rmse: 3.77361
# [1000]	training's rmse: 3.85705	valid_1's rmse: 3.7736
# Early stopping, best iteration is:
# [634]	training's rmse: 3.85706	valid_1's rmse: 3.77357
# fold n°3
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85044	valid_1's rmse: 3.83392
# Early stopping, best iteration is:
# [462]	training's rmse: 3.85045	valid_1's rmse: 3.83389
# fold n°4
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.86771	valid_1's rmse: 3.67421
# Early stopping, best iteration is:
# [312]	training's rmse: 3.86778	valid_1's rmse: 3.67414
# fold n°5
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84531	valid_1's rmse: 3.88034
# [1000]	training's rmse: 3.84529	valid_1's rmse: 3.8802
# [1500]	training's rmse: 3.84529	valid_1's rmse: 3.88019
# Early stopping, best iteration is:
# [1239]	training's rmse: 3.84529	valid_1's rmse: 3.88018
# fold n°6
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.82866	valid_1's rmse: 4.02546
# Early stopping, best iteration is:
# [103]	training's rmse: 3.82927	valid_1's rmse: 4.025
# fold n°7
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8381	valid_1's rmse: 3.94397
# [1000]	training's rmse: 3.83808	valid_1's rmse: 3.94389
# [1500]	training's rmse: 3.83808	valid_1's rmse: 3.94385
# Early stopping, best iteration is:
# [1237]	training's rmse: 3.83808	valid_1's rmse: 3.94384
# fold n°8
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85087	valid_1's rmse: 3.83013
# [1000]	training's rmse: 3.85085	valid_1's rmse: 3.83025
# Early stopping, best iteration is:
# [659]	training's rmse: 3.85085	valid_1's rmse: 3.83011
# fold n°9
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85922	valid_1's rmse: 3.75364
# Early stopping, best iteration is:
# [240]	training's rmse: 3.85939	valid_1's rmse: 3.75353
# |  6        | -3.849    |  0.3687   |  0.6893   |  0.4678   |  15.23    |  198.8    |  199.1    |
# fold n°0
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84136	valid_1's rmse: 3.92188
# [1000]	training's rmse: 3.84125	valid_1's rmse: 3.92177
# [1500]	training's rmse: 3.84123	valid_1's rmse: 3.9218
# Early stopping, best iteration is:
# [1083]	training's rmse: 3.84124	valid_1's rmse: 3.92176
# fold n°1
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85019	valid_1's rmse: 3.84312
# [1000]	training's rmse: 3.8501	valid_1's rmse: 3.84294
# [1500]	training's rmse: 3.85009	valid_1's rmse: 3.8429
# [2000]	training's rmse: 3.85009	valid_1's rmse: 3.84286
# [2500]	training's rmse: 3.85009	valid_1's rmse: 3.84287
# Early stopping, best iteration is:
# [2136]	training's rmse: 3.85009	valid_1's rmse: 3.84285
# fold n°2
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85768	valid_1's rmse: 3.77478
# [1000]	training's rmse: 3.85758	valid_1's rmse: 3.77476
# Early stopping, best iteration is:
# [737]	training's rmse: 3.85761	valid_1's rmse: 3.77474
# fold n°3
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85117	valid_1's rmse: 3.83415
# [1000]	training's rmse: 3.85108	valid_1's rmse: 3.83406
# [1500]	training's rmse: 3.85106	valid_1's rmse: 3.83406
# Early stopping, best iteration is:
# [1169]	training's rmse: 3.85107	valid_1's rmse: 3.83403
# fold n°4
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.86843	valid_1's rmse: 3.6746
# [1000]	training's rmse: 3.86833	valid_1's rmse: 3.67453
# [1500]	training's rmse: 3.86831	valid_1's rmse: 3.6745
# Early stopping, best iteration is:
# [1407]	training's rmse: 3.86831	valid_1's rmse: 3.67446
# fold n°5
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84594	valid_1's rmse: 3.88124
# [1000]	training's rmse: 3.84583	valid_1's rmse: 3.88117
# [1500]	training's rmse: 3.84581	valid_1's rmse: 3.88121
# Early stopping, best iteration is:
# [1162]	training's rmse: 3.84582	valid_1's rmse: 3.88115
# fold n°6
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.82943	valid_1's rmse: 4.02522
# Early stopping, best iteration is:
# [180]	training's rmse: 3.82982	valid_1's rmse: 4.02515
# fold n°7
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.83875	valid_1's rmse: 3.94506
# [1000]	training's rmse: 3.83865	valid_1's rmse: 3.94476
# [1500]	training's rmse: 3.83864	valid_1's rmse: 3.94466
# [2000]	training's rmse: 3.83864	valid_1's rmse: 3.94461
# Early stopping, best iteration is:
# [1759]	training's rmse: 3.83864	valid_1's rmse: 3.94463
# fold n°8
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85161	valid_1's rmse: 3.8305
# [1000]	training's rmse: 3.85151	valid_1's rmse: 3.83033
# [1500]	training's rmse: 3.85149	valid_1's rmse: 3.83024
# [2000]	training's rmse: 3.85149	valid_1's rmse: 3.83026
# Early stopping, best iteration is:
# [1672]	training's rmse: 3.85149	valid_1's rmse: 3.83021
# fold n°9
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.86	valid_1's rmse: 3.75355
# [1000]	training's rmse: 3.85989	valid_1's rmse: 3.7535
# Early stopping, best iteration is:
# [916]	training's rmse: 3.85989	valid_1's rmse: 3.75347
# |  7        | -3.849    |  0.3417   |  0.2607   |  0.06679  |  1.441    |  199.7    |  197.4    |
# fold n°0
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84127	valid_1's rmse: 3.92179
# [1000]	training's rmse: 3.84123	valid_1's rmse: 3.92179
# Early stopping, best iteration is:
# [724]	training's rmse: 3.84124	valid_1's rmse: 3.92177
# fold n°1
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85013	valid_1's rmse: 3.84298
# [1000]	training's rmse: 3.85009	valid_1's rmse: 3.84288
# [1500]	training's rmse: 3.85009	valid_1's rmse: 3.84288
# [2000]	training's rmse: 3.85009	valid_1's rmse: 3.84287
# Early stopping, best iteration is:
# [1652]	training's rmse: 3.85009	valid_1's rmse: 3.84287
# fold n°2
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8576	valid_1's rmse: 3.77474
# Early stopping, best iteration is:
# [414]	training's rmse: 3.85764	valid_1's rmse: 3.77473
# fold n°3
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8511	valid_1's rmse: 3.83409
# [1000]	training's rmse: 3.85106	valid_1's rmse: 3.83404
# [1500]	training's rmse: 3.85106	valid_1's rmse: 3.83404
# Early stopping, best iteration is:
# [1265]	training's rmse: 3.85106	valid_1's rmse: 3.83404
# fold n°4
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.86834	valid_1's rmse: 3.67456
# [1000]	training's rmse: 3.86831	valid_1's rmse: 3.67453
# [1500]	training's rmse: 3.86831	valid_1's rmse: 3.67453
# Early stopping, best iteration is:
# [1153]	training's rmse: 3.86831	valid_1's rmse: 3.67451
# fold n°5
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84586	valid_1's rmse: 3.88118
# [1000]	training's rmse: 3.84581	valid_1's rmse: 3.88118
# Early stopping, best iteration is:
# [678]	training's rmse: 3.84583	valid_1's rmse: 3.88115
# fold n°6
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.82935	valid_1's rmse: 4.02532
# Early stopping, best iteration is:
# [148]	training's rmse: 3.82975	valid_1's rmse: 4.02519
# fold n°7
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.83868	valid_1's rmse: 3.94481
# [1000]	training's rmse: 3.83864	valid_1's rmse: 3.94465
# [1500]	training's rmse: 3.83864	valid_1's rmse: 3.94463
# [2000]	training's rmse: 3.83864	valid_1's rmse: 3.94463
# Early stopping, best iteration is:
# [1846]	training's rmse: 3.83864	valid_1's rmse: 3.94461
# fold n°8
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85153	valid_1's rmse: 3.83039
# [1000]	training's rmse: 3.85149	valid_1's rmse: 3.83026
# [1500]	training's rmse: 3.85149	valid_1's rmse: 3.83022
# [2000]	training's rmse: 3.85149	valid_1's rmse: 3.83024
# Early stopping, best iteration is:
# [1608]	training's rmse: 3.85149	valid_1's rmse: 3.83022
# fold n°9
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85991	valid_1's rmse: 3.7535
# [1000]	training's rmse: 3.85988	valid_1's rmse: 3.75348
# Early stopping, best iteration is:
# [964]	training's rmse: 3.85988	valid_1's rmse: 3.75347
# |  8        | -3.849    |  0.691    |  0.7468   |  0.2261   |  19.92    |  198.2    |  2.228    |
# fold n°0
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84077	valid_1's rmse: 3.9207
# [1000]	training's rmse: 3.84074	valid_1's rmse: 3.92056
# [1500]	training's rmse: 3.84073	valid_1's rmse: 3.92052
# [2000]	training's rmse: 3.84073	valid_1's rmse: 3.9205
# [2500]	training's rmse: 3.84073	valid_1's rmse: 3.92051
# Early stopping, best iteration is:
# [2017]	training's rmse: 3.84073	valid_1's rmse: 3.9205
# fold n°1
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84947	valid_1's rmse: 3.84303
# Early stopping, best iteration is:
# [296]	training's rmse: 3.84959	valid_1's rmse: 3.84301
# fold n°2
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85709	valid_1's rmse: 3.77367
# [1000]	training's rmse: 3.85706	valid_1's rmse: 3.77359
# [1500]	training's rmse: 3.85705	valid_1's rmse: 3.77358
# [2000]	training's rmse: 3.85705	valid_1's rmse: 3.77356
# [2500]	training's rmse: 3.85705	valid_1's rmse: 3.77357
# Early stopping, best iteration is:
# [2182]	training's rmse: 3.85705	valid_1's rmse: 3.77355
# fold n°3
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85047	valid_1's rmse: 3.83397
# [1000]	training's rmse: 3.85043	valid_1's rmse: 3.83395
# [1500]	training's rmse: 3.85043	valid_1's rmse: 3.83395
# [2000]	training's rmse: 3.85043	valid_1's rmse: 3.83393
# [2500]	training's rmse: 3.85043	valid_1's rmse: 3.83393
# Early stopping, best iteration is:
# [2281]	training's rmse: 3.85043	valid_1's rmse: 3.83392
# fold n°4
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.86774	valid_1's rmse: 3.67419
# Early stopping, best iteration is:
# [308]	training's rmse: 3.86784	valid_1's rmse: 3.67414
# fold n°5
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84533	valid_1's rmse: 3.88036
# [1000]	training's rmse: 3.84529	valid_1's rmse: 3.88021
# [1500]	training's rmse: 3.84529	valid_1's rmse: 3.88018
# [2000]	training's rmse: 3.84529	valid_1's rmse: 3.88018
# Early stopping, best iteration is:
# [1815]	training's rmse: 3.84529	valid_1's rmse: 3.88015
# fold n°6
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.82871	valid_1's rmse: 4.02527
# Early stopping, best iteration is:
# [152]	training's rmse: 3.82916	valid_1's rmse: 4.02493
# fold n°7
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.83813	valid_1's rmse: 3.94392
# [1000]	training's rmse: 3.83808	valid_1's rmse: 3.94386
# [1500]	training's rmse: 3.83808	valid_1's rmse: 3.94386
# Early stopping, best iteration is:
# [1051]	training's rmse: 3.83808	valid_1's rmse: 3.94385
# fold n°8
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85089	valid_1's rmse: 3.83011
# [1000]	training's rmse: 3.85085	valid_1's rmse: 3.83016
# Early stopping, best iteration is:
# [568]	training's rmse: 3.85088	valid_1's rmse: 3.8301
# fold n°9
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85925	valid_1's rmse: 3.75364
# Early stopping, best iteration is:
# [252]	training's rmse: 3.85943	valid_1's rmse: 3.75356
# |  9        | -3.849    |  0.8698   |  0.8463   |  1.029    |  3.557    |  1.101    |  198.4    |
# fold n°0
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84132	valid_1's rmse: 3.92185
# [1000]	training's rmse: 3.84124	valid_1's rmse: 3.92179
# Early stopping, best iteration is:
# [972]	training's rmse: 3.84124	valid_1's rmse: 3.92179
# fold n°1
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85016	valid_1's rmse: 3.84307
# [1000]	training's rmse: 3.8501	valid_1's rmse: 3.84293
# [1500]	training's rmse: 3.85009	valid_1's rmse: 3.84288
# [2000]	training's rmse: 3.85009	valid_1's rmse: 3.84287
# [2500]	training's rmse: 3.85009	valid_1's rmse: 3.84286
# Early stopping, best iteration is:
# [2318]	training's rmse: 3.85009	valid_1's rmse: 3.84286
# fold n°2
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85765	valid_1's rmse: 3.77475
# [1000]	training's rmse: 3.85757	valid_1's rmse: 3.77476
# Early stopping, best iteration is:
# [705]	training's rmse: 3.85759	valid_1's rmse: 3.77474
# fold n°3
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85114	valid_1's rmse: 3.83411
# [1000]	training's rmse: 3.85107	valid_1's rmse: 3.83405
# [1500]	training's rmse: 3.85106	valid_1's rmse: 3.83404
# [2000]	training's rmse: 3.85106	valid_1's rmse: 3.83404
# [2500]	training's rmse: 3.85106	valid_1's rmse: 3.83404
# Early stopping, best iteration is:
# [2116]	training's rmse: 3.85106	valid_1's rmse: 3.83403
# fold n°4
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8684	valid_1's rmse: 3.6745
# [1000]	training's rmse: 3.86832	valid_1's rmse: 3.6745
# Early stopping, best iteration is:
# [801]	training's rmse: 3.86833	valid_1's rmse: 3.67448
# fold n°5
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84589	valid_1's rmse: 3.88127
# [1000]	training's rmse: 3.84582	valid_1's rmse: 3.8812
# [1500]	training's rmse: 3.84581	valid_1's rmse: 3.8812
# Early stopping, best iteration is:
# [1168]	training's rmse: 3.84581	valid_1's rmse: 3.88119
# fold n°6
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.82939	valid_1's rmse: 4.02529
# Early stopping, best iteration is:
# [192]	training's rmse: 3.82971	valid_1's rmse: 4.02518
# fold n°7
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.83871	valid_1's rmse: 3.94496
# [1000]	training's rmse: 3.83864	valid_1's rmse: 3.94472
# [1500]	training's rmse: 3.83864	valid_1's rmse: 3.94466
# [2000]	training's rmse: 3.83864	valid_1's rmse: 3.94464
# [2500]	training's rmse: 3.83864	valid_1's rmse: 3.94463
# [3000]	training's rmse: 3.83864	valid_1's rmse: 3.94463
# Early stopping, best iteration is:
# [2626]	training's rmse: 3.83864	valid_1's rmse: 3.94463
# fold n°8
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85157	valid_1's rmse: 3.83042
# [1000]	training's rmse: 3.8515	valid_1's rmse: 3.83028
# [1500]	training's rmse: 3.85149	valid_1's rmse: 3.83024
# [2000]	training's rmse: 3.85149	valid_1's rmse: 3.83024
# Early stopping, best iteration is:
# [1889]	training's rmse: 3.85149	valid_1's rmse: 3.83023
# fold n°9
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85996	valid_1's rmse: 3.75348
# [1000]	training's rmse: 3.85988	valid_1's rmse: 3.75347
# Early stopping, best iteration is:
# [559]	training's rmse: 3.85994	valid_1's rmse: 3.75346
# |  10       | -3.849    |  0.9192   |  0.6202   |  1.488    |  17.59    |  1.515    |  200.0    |
# fold n°0
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84126	valid_1's rmse: 3.92179
# [1000]	training's rmse: 3.84123	valid_1's rmse: 3.9218
# Early stopping, best iteration is:
# [612]	training's rmse: 3.84125	valid_1's rmse: 3.92177
# fold n°1
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85012	valid_1's rmse: 3.84297
# [1000]	training's rmse: 3.85009	valid_1's rmse: 3.84291
# [1500]	training's rmse: 3.85009	valid_1's rmse: 3.84286
# [2000]	training's rmse: 3.85009	valid_1's rmse: 3.84287
# Early stopping, best iteration is:
# [1543]	training's rmse: 3.85009	valid_1's rmse: 3.84286
# fold n°2
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8576	valid_1's rmse: 3.77473
# Early stopping, best iteration is:
# [414]	training's rmse: 3.85763	valid_1's rmse: 3.77471
# fold n°3
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85109	valid_1's rmse: 3.83408
# [1000]	training's rmse: 3.85106	valid_1's rmse: 3.83403
# [1500]	training's rmse: 3.85106	valid_1's rmse: 3.83404
# Early stopping, best iteration is:
# [1239]	training's rmse: 3.85106	valid_1's rmse: 3.83402
# fold n°4
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.86834	valid_1's rmse: 3.67457
# [1000]	training's rmse: 3.86831	valid_1's rmse: 3.67453
# [1500]	training's rmse: 3.86831	valid_1's rmse: 3.67453
# Early stopping, best iteration is:
# [1402]	training's rmse: 3.86831	valid_1's rmse: 3.67449
# fold n°5
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84585	valid_1's rmse: 3.8812
# [1000]	training's rmse: 3.84581	valid_1's rmse: 3.88118
# Early stopping, best iteration is:
# [685]	training's rmse: 3.84582	valid_1's rmse: 3.88115
# fold n°6
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.82934	valid_1's rmse: 4.02532
# Early stopping, best iteration is:
# [170]	training's rmse: 3.82968	valid_1's rmse: 4.02517
# fold n°7
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.83867	valid_1's rmse: 3.9448
# [1000]	training's rmse: 3.83864	valid_1's rmse: 3.94464
# [1500]	training's rmse: 3.83864	valid_1's rmse: 3.94463
# [2000]	training's rmse: 3.83864	valid_1's rmse: 3.94461
# Early stopping, best iteration is:
# [1986]	training's rmse: 3.83864	valid_1's rmse: 3.9446
# fold n°8
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85153	valid_1's rmse: 3.83037
# [1000]	training's rmse: 3.85149	valid_1's rmse: 3.83027
# [1500]	training's rmse: 3.85149	valid_1's rmse: 3.83021
# [2000]	training's rmse: 3.85149	valid_1's rmse: 3.83025
# Early stopping, best iteration is:
# [1514]	training's rmse: 3.85149	valid_1's rmse: 3.83021
# fold n°9
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85991	valid_1's rmse: 3.75348
# [1000]	training's rmse: 3.85987	valid_1's rmse: 3.75348
# Early stopping, best iteration is:
# [742]	training's rmse: 3.85988	valid_1's rmse: 3.75345
# |  11       | -3.849    |  0.5332   |  0.9332   |  2.817    |  1.637    |  2.222    |  3.593    |
# fold n°0
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84126	valid_1's rmse: 3.92179
# [1000]	training's rmse: 3.84123	valid_1's rmse: 3.9218
# Early stopping, best iteration is:
# [612]	training's rmse: 3.84125	valid_1's rmse: 3.92176
# fold n°1
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85012	valid_1's rmse: 3.84297
# [1000]	training's rmse: 3.85009	valid_1's rmse: 3.84289
# [1500]	training's rmse: 3.85009	valid_1's rmse: 3.84286
# [2000]	training's rmse: 3.85009	valid_1's rmse: 3.84286
# Early stopping, best iteration is:
# [1550]	training's rmse: 3.85009	valid_1's rmse: 3.84286
# fold n°2
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8576	valid_1's rmse: 3.77474
# Early stopping, best iteration is:
# [353]	training's rmse: 3.85766	valid_1's rmse: 3.77471
# fold n°3
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85109	valid_1's rmse: 3.83407
# [1000]	training's rmse: 3.85106	valid_1's rmse: 3.83403
# [1500]	training's rmse: 3.85106	valid_1's rmse: 3.83404
# Early stopping, best iteration is:
# [1307]	training's rmse: 3.85106	valid_1's rmse: 3.83401
# fold n°4
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.86834	valid_1's rmse: 3.67457
# [1000]	training's rmse: 3.86831	valid_1's rmse: 3.67453
# [1500]	training's rmse: 3.86831	valid_1's rmse: 3.67453
# Early stopping, best iteration is:
# [1164]	training's rmse: 3.86831	valid_1's rmse: 3.67449
# fold n°5
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84586	valid_1's rmse: 3.88121
# [1000]	training's rmse: 3.84581	valid_1's rmse: 3.88118
# Early stopping, best iteration is:
# [685]	training's rmse: 3.84582	valid_1's rmse: 3.88115
# fold n°6
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.82934	valid_1's rmse: 4.02533
# Early stopping, best iteration is:
# [188]	training's rmse: 3.82964	valid_1's rmse: 4.02517
# fold n°7
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.83867	valid_1's rmse: 3.9448
# [1000]	training's rmse: 3.83864	valid_1's rmse: 3.94464
# [1500]	training's rmse: 3.83864	valid_1's rmse: 3.94463
# [2000]	training's rmse: 3.83864	valid_1's rmse: 3.94461
# Early stopping, best iteration is:
# [1522]	training's rmse: 3.83864	valid_1's rmse: 3.94463
# fold n°8
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85153	valid_1's rmse: 3.83038
# [1000]	training's rmse: 3.85149	valid_1's rmse: 3.83026
# [1500]	training's rmse: 3.85149	valid_1's rmse: 3.83021
# [2000]	training's rmse: 3.85149	valid_1's rmse: 3.83025
# Early stopping, best iteration is:
# [1514]	training's rmse: 3.85149	valid_1's rmse: 3.83021
# fold n°9
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85991	valid_1's rmse: 3.75349
# [1000]	training's rmse: 3.85987	valid_1's rmse: 3.75347
# Early stopping, best iteration is:
# [744]	training's rmse: 3.85988	valid_1's rmse: 3.75345
# |  12       | -3.849    |  0.527    |  0.7046   |  5.694    |  1.544    |  197.4    |  199.0    |
# fold n°0
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84128	valid_1's rmse: 3.92179
# [1000]	training's rmse: 3.84123	valid_1's rmse: 3.92179
# Early stopping, best iteration is:
# [748]	training's rmse: 3.84124	valid_1's rmse: 3.92177
# fold n°1
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85013	valid_1's rmse: 3.84297
# [1000]	training's rmse: 3.85009	valid_1's rmse: 3.84289
# [1500]	training's rmse: 3.85009	valid_1's rmse: 3.84286
# [2000]	training's rmse: 3.85009	valid_1's rmse: 3.84286
# Early stopping, best iteration is:
# [1652]	training's rmse: 3.85009	valid_1's rmse: 3.84285
# fold n°2
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85761	valid_1's rmse: 3.77474
# Early stopping, best iteration is:
# [395]	training's rmse: 3.85766	valid_1's rmse: 3.77473
# fold n°3
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8511	valid_1's rmse: 3.83409
# [1000]	training's rmse: 3.85106	valid_1's rmse: 3.83405
# [1500]	training's rmse: 3.85106	valid_1's rmse: 3.83405
# Early stopping, best iteration is:
# [1223]	training's rmse: 3.85106	valid_1's rmse: 3.83403
# fold n°4
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.86835	valid_1's rmse: 3.67455
# [1000]	training's rmse: 3.86831	valid_1's rmse: 3.67454
# [1500]	training's rmse: 3.86831	valid_1's rmse: 3.67453
# [2000]	training's rmse: 3.86831	valid_1's rmse: 3.67452
# [2500]	training's rmse: 3.86831	valid_1's rmse: 3.67449
# Early stopping, best iteration is:
# [2146]	training's rmse: 3.86831	valid_1's rmse: 3.67452
# fold n°5
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84587	valid_1's rmse: 3.88119
# [1000]	training's rmse: 3.84581	valid_1's rmse: 3.88118
# Early stopping, best iteration is:
# [687]	training's rmse: 3.84583	valid_1's rmse: 3.88116
# fold n°6
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.82936	valid_1's rmse: 4.02532
# Early stopping, best iteration is:
# [196]	training's rmse: 3.82964	valid_1's rmse: 4.02519
# fold n°7
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.83868	valid_1's rmse: 3.94481
# [1000]	training's rmse: 3.83864	valid_1's rmse: 3.94466
# [1500]	training's rmse: 3.83864	valid_1's rmse: 3.94463
# [2000]	training's rmse: 3.83864	valid_1's rmse: 3.94462
# [2500]	training's rmse: 3.83864	valid_1's rmse: 3.94463
# Early stopping, best iteration is:
# [2030]	training's rmse: 3.83864	valid_1's rmse: 3.94462
# fold n°8
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85153	valid_1's rmse: 3.8304
# [1000]	training's rmse: 3.85149	valid_1's rmse: 3.83026
# [1500]	training's rmse: 3.85149	valid_1's rmse: 3.83023
# [2000]	training's rmse: 3.85149	valid_1's rmse: 3.83024
# Early stopping, best iteration is:
# [1578]	training's rmse: 3.85149	valid_1's rmse: 3.83022
# fold n°9
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85992	valid_1's rmse: 3.75352
# [1000]	training's rmse: 3.85988	valid_1's rmse: 3.75348
# Early stopping, best iteration is:
# [963]	training's rmse: 3.85988	valid_1's rmse: 3.75347
# |  13       | -3.849    |  0.8464   |  0.8474   |  4.282    |  1.631    |  1.278    |  199.8    |
# fold n°0
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84136	valid_1's rmse: 3.92186
# [1000]	training's rmse: 3.84125	valid_1's rmse: 3.92178
# [1500]	training's rmse: 3.84123	valid_1's rmse: 3.92178
# Early stopping, best iteration is:
# [1120]	training's rmse: 3.84124	valid_1's rmse: 3.92177
# fold n°1
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85021	valid_1's rmse: 3.84318
# [1000]	training's rmse: 3.8501	valid_1's rmse: 3.84296
# [1500]	training's rmse: 3.85009	valid_1's rmse: 3.84291
# [2000]	training's rmse: 3.85009	valid_1's rmse: 3.84289
# [2500]	training's rmse: 3.85009	valid_1's rmse: 3.84287
# [3000]	training's rmse: 3.85009	valid_1's rmse: 3.84286
# Early stopping, best iteration is:
# [2704]	training's rmse: 3.85009	valid_1's rmse: 3.84286
# fold n°2
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85769	valid_1's rmse: 3.77479
# [1000]	training's rmse: 3.85757	valid_1's rmse: 3.77476
# Early stopping, best iteration is:
# [814]	training's rmse: 3.85759	valid_1's rmse: 3.77475
# fold n°3
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85118	valid_1's rmse: 3.83418
# [1000]	training's rmse: 3.85108	valid_1's rmse: 3.83406
# [1500]	training's rmse: 3.85106	valid_1's rmse: 3.83404
# Early stopping, best iteration is:
# [1362]	training's rmse: 3.85106	valid_1's rmse: 3.83403
# fold n°4
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.86843	valid_1's rmse: 3.67459
# [1000]	training's rmse: 3.86833	valid_1's rmse: 3.67453
# [1500]	training's rmse: 3.86831	valid_1's rmse: 3.6745
# Early stopping, best iteration is:
# [1411]	training's rmse: 3.86831	valid_1's rmse: 3.67448
# fold n°5
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84595	valid_1's rmse: 3.88123
# [1000]	training's rmse: 3.84583	valid_1's rmse: 3.88115
# [1500]	training's rmse: 3.84581	valid_1's rmse: 3.88118
# Early stopping, best iteration is:
# [1054]	training's rmse: 3.84583	valid_1's rmse: 3.88114
# fold n°6
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.82944	valid_1's rmse: 4.02519
# Early stopping, best iteration is:
# [196]	training's rmse: 3.82978	valid_1's rmse: 4.02515
# fold n°7
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.83874	valid_1's rmse: 3.94504
# [1000]	training's rmse: 3.83865	valid_1's rmse: 3.94475
# [1500]	training's rmse: 3.83864	valid_1's rmse: 3.94466
# [2000]	training's rmse: 3.83864	valid_1's rmse: 3.94462
# Early stopping, best iteration is:
# [1992]	training's rmse: 3.83864	valid_1's rmse: 3.94462
# fold n°8
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85163	valid_1's rmse: 3.83051
# [1000]	training's rmse: 3.85151	valid_1's rmse: 3.83033
# [1500]	training's rmse: 3.85149	valid_1's rmse: 3.83025
# [2000]	training's rmse: 3.85149	valid_1's rmse: 3.83024
# [2500]	training's rmse: 3.85149	valid_1's rmse: 3.83023
# Early stopping, best iteration is:
# [2155]	training's rmse: 3.85149	valid_1's rmse: 3.83023
# fold n°9
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.86001	valid_1's rmse: 3.7535
# [1000]	training's rmse: 3.85989	valid_1's rmse: 3.75346
# Early stopping, best iteration is:
# [786]	training's rmse: 3.85991	valid_1's rmse: 3.75345
# |  14       | -3.849    |  0.613    |  0.3619   |  1.42     |  19.93    |  199.3    |  2.765    |
# fold n°0
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84126	valid_1's rmse: 3.92181
# [1000]	training's rmse: 3.84123	valid_1's rmse: 3.92179
# [1500]	training's rmse: 3.84123	valid_1's rmse: 3.92179
# Early stopping, best iteration is:
# [1367]	training's rmse: 3.84123	valid_1's rmse: 3.9218
# fold n°1
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85012	valid_1's rmse: 3.84296
# [1000]	training's rmse: 3.85009	valid_1's rmse: 3.84289
# [1500]	training's rmse: 3.85009	valid_1's rmse: 3.84288
# Early stopping, best iteration is:
# [1169]	training's rmse: 3.85009	valid_1's rmse: 3.84281
# fold n°2
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8576	valid_1's rmse: 3.77473
# Early stopping, best iteration is:
# [400]	training's rmse: 3.85763	valid_1's rmse: 3.77471
# fold n°3
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85109	valid_1's rmse: 3.83406
# [1000]	training's rmse: 3.85106	valid_1's rmse: 3.83406
# Early stopping, best iteration is:
# [953]	training's rmse: 3.85106	valid_1's rmse: 3.83403
# fold n°4
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.86834	valid_1's rmse: 3.6746
# [1000]	training's rmse: 3.86831	valid_1's rmse: 3.6745
# [1500]	training's rmse: 3.86831	valid_1's rmse: 3.6745
# Early stopping, best iteration is:
# [1243]	training's rmse: 3.86831	valid_1's rmse: 3.67446
# fold n°5
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84585	valid_1's rmse: 3.88121
# [1000]	training's rmse: 3.84581	valid_1's rmse: 3.88118
# Early stopping, best iteration is:
# [661]	training's rmse: 3.84583	valid_1's rmse: 3.88116
# fold n°6
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.82933	valid_1's rmse: 4.02537
# Early stopping, best iteration is:
# [183]	training's rmse: 3.82962	valid_1's rmse: 4.02515
# fold n°7
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.83866	valid_1's rmse: 3.94479
# [1000]	training's rmse: 3.83864	valid_1's rmse: 3.94463
# [1500]	training's rmse: 3.83864	valid_1's rmse: 3.94465
# Early stopping, best iteration is:
# [1237]	training's rmse: 3.83864	valid_1's rmse: 3.94459
# fold n°8
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85152	valid_1's rmse: 3.83037
# [1000]	training's rmse: 3.85149	valid_1's rmse: 3.83022
# [1500]	training's rmse: 3.85149	valid_1's rmse: 3.83022
# Early stopping, best iteration is:
# [1143]	training's rmse: 3.85149	valid_1's rmse: 3.83024
# fold n°9
# Training until validation scores don't improve for 500 rounds.
# ...
# [1500]	training's rmse: 3.85106	valid_1's rmse: 3.83404
# Early stopping, best iteration is:
# [1246]	training's rmse: 3.85106	valid_1's rmse: 3.83402
# fold n°4
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.86834	valid_1's rmse: 3.67458
# [1000]	training's rmse: 3.86831	valid_1's rmse: 3.67453
# [1500]	training's rmse: 3.86831	valid_1's rmse: 3.67451
# Early stopping, best iteration is:
# [1405]	training's rmse: 3.86831	valid_1's rmse: 3.67448
# fold n°5
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84585	valid_1's rmse: 3.8812
# [1000]	training's rmse: 3.84581	valid_1's rmse: 3.88118
# Early stopping, best iteration is:
# [648]	training's rmse: 3.84583	valid_1's rmse: 3.88116
# fold n°6
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.82934	valid_1's rmse: 4.02534
# Early stopping, best iteration is:
# [176]	training's rmse: 3.82966	valid_1's rmse: 4.02515
# fold n°7
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.83867	valid_1's rmse: 3.94479
# [1000]	training's rmse: 3.83864	valid_1's rmse: 3.94463
# [1500]	training's rmse: 3.83864	valid_1's rmse: 3.94462
# [2000]	training's rmse: 3.83864	valid_1's rmse: 3.94461
# Early stopping, best iteration is:
# [1516]	training's rmse: 3.83864	valid_1's rmse: 3.94464
# fold n°8
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85152	valid_1's rmse: 3.83036
# [1000]	training's rmse: 3.85149	valid_1's rmse: 3.83027
# [1500]	training's rmse: 3.85149	valid_1's rmse: 3.83023
# [2000]	training's rmse: 3.85149	valid_1's rmse: 3.83023
# Early stopping, best iteration is:
# [1691]	training's rmse: 3.85149	valid_1's rmse: 3.83021
# fold n°9
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85991	valid_1's rmse: 3.75348
# [1000]	training's rmse: 3.85988	valid_1's rmse: 3.75348
# Early stopping, best iteration is:
# [737]	training's rmse: 3.85988	valid_1's rmse: 3.75345
# |  18       | -3.849    |  0.4026   |  0.7091   |  5.112    |  1.192    |  199.5    |  2.456    |
# fold n°0
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84131	valid_1's rmse: 3.92185
# [1000]	training's rmse: 3.84124	valid_1's rmse: 3.92179
# [1500]	training's rmse: 3.84123	valid_1's rmse: 3.9218
# Early stopping, best iteration is:
# [1191]	training's rmse: 3.84123	valid_1's rmse: 3.92178
# fold n°1
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85016	valid_1's rmse: 3.84307
# [1000]	training's rmse: 3.85009	valid_1's rmse: 3.84291
# [1500]	training's rmse: 3.85009	valid_1's rmse: 3.84288
# Early stopping, best iteration is:
# [1248]	training's rmse: 3.85009	valid_1's rmse: 3.84286
# fold n°2
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85765	valid_1's rmse: 3.77476
# [1000]	training's rmse: 3.85757	valid_1's rmse: 3.77478
# Early stopping, best iteration is:
# [635]	training's rmse: 3.85761	valid_1's rmse: 3.77474
# fold n°3
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85115	valid_1's rmse: 3.83411
# [1000]	training's rmse: 3.85107	valid_1's rmse: 3.83405
# [1500]	training's rmse: 3.85106	valid_1's rmse: 3.83405
# Early stopping, best iteration is:
# [1187]	training's rmse: 3.85107	valid_1's rmse: 3.83403
# fold n°4
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8684	valid_1's rmse: 3.67453
# [1000]	training's rmse: 3.86832	valid_1's rmse: 3.67451
# [1500]	training's rmse: 3.86831	valid_1's rmse: 3.67451
# Early stopping, best iteration is:
# [1271]	training's rmse: 3.86832	valid_1's rmse: 3.67449
# fold n°5
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84591	valid_1's rmse: 3.88129
# [1000]	training's rmse: 3.84582	valid_1's rmse: 3.88121
# [1500]	training's rmse: 3.84581	valid_1's rmse: 3.88119
# [2000]	training's rmse: 3.84581	valid_1's rmse: 3.88117
# [2500]	training's rmse: 3.84581	valid_1's rmse: 3.88119
# Early stopping, best iteration is:
# [2003]	training's rmse: 3.84581	valid_1's rmse: 3.88117
# fold n°6
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8294	valid_1's rmse: 4.02525
# Early stopping, best iteration is:
# [173]	training's rmse: 3.82978	valid_1's rmse: 4.02516
# fold n°7
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.83871	valid_1's rmse: 3.94497
# [1000]	training's rmse: 3.83864	valid_1's rmse: 3.94473
# [1500]	training's rmse: 3.83864	valid_1's rmse: 3.94469
# [2000]	training's rmse: 3.83864	valid_1's rmse: 3.94462
# [2500]	training's rmse: 3.83864	valid_1's rmse: 3.94462
# Early stopping, best iteration is:
# [2343]	training's rmse: 3.83864	valid_1's rmse: 3.94459
# fold n°8
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85157	valid_1's rmse: 3.83045
# [1000]	training's rmse: 3.8515	valid_1's rmse: 3.83029
# [1500]	training's rmse: 3.85149	valid_1's rmse: 3.83023
# [2000]	training's rmse: 3.85149	valid_1's rmse: 3.83025
# Early stopping, best iteration is:
# [1765]	training's rmse: 3.85149	valid_1's rmse: 3.83021
# fold n°9
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85996	valid_1's rmse: 3.7535
# [1000]	training's rmse: 3.85988	valid_1's rmse: 3.75347
# Early stopping, best iteration is:
# [704]	training's rmse: 3.85991	valid_1's rmse: 3.75346
# |  19       | -3.849    |  0.424    |  0.205    |  3.586    |  19.84    |  1.237    |  4.717    |
# fold n°0
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84127	valid_1's rmse: 3.92179
# [1000]	training's rmse: 3.84123	valid_1's rmse: 3.9218
# Early stopping, best iteration is:
# [731]	training's rmse: 3.84124	valid_1's rmse: 3.92177
# fold n°1
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85012	valid_1's rmse: 3.84298
# [1000]	training's rmse: 3.85009	valid_1's rmse: 3.84289
# [1500]	training's rmse: 3.85009	valid_1's rmse: 3.84287
# [2000]	training's rmse: 3.85009	valid_1's rmse: 3.84287
# Early stopping, best iteration is:
# [1678]	training's rmse: 3.85009	valid_1's rmse: 3.84287
# fold n°2
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8576	valid_1's rmse: 3.77474
# Early stopping, best iteration is:
# [353]	training's rmse: 3.85767	valid_1's rmse: 3.77472
# fold n°3
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85109	valid_1's rmse: 3.83409
# [1000]	training's rmse: 3.85106	valid_1's rmse: 3.83403
# Early stopping, best iteration is:
# [958]	training's rmse: 3.85106	valid_1's rmse: 3.83403
# fold n°4
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.86834	valid_1's rmse: 3.67454
# [1000]	training's rmse: 3.86831	valid_1's rmse: 3.67452
# [1500]	training's rmse: 3.86831	valid_1's rmse: 3.67452
# Early stopping, best iteration is:
# [1164]	training's rmse: 3.86831	valid_1's rmse: 3.67449
# fold n°5
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84586	valid_1's rmse: 3.88119
# [1000]	training's rmse: 3.84581	valid_1's rmse: 3.88118
# Early stopping, best iteration is:
# [685]	training's rmse: 3.84582	valid_1's rmse: 3.88115
# fold n°6
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.82935	valid_1's rmse: 4.02531
# Early stopping, best iteration is:
# [188]	training's rmse: 3.82965	valid_1's rmse: 4.02518
# fold n°7
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.83867	valid_1's rmse: 3.9448
# [1000]	training's rmse: 3.83864	valid_1's rmse: 3.94464
# [1500]	training's rmse: 3.83864	valid_1's rmse: 3.94462
# [2000]	training's rmse: 3.83864	valid_1's rmse: 3.94463
# Early stopping, best iteration is:
# [1657]	training's rmse: 3.83864	valid_1's rmse: 3.94461
# fold n°8
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85153	valid_1's rmse: 3.83038
# [1000]	training's rmse: 3.85149	valid_1's rmse: 3.83027
# [1500]	training's rmse: 3.85149	valid_1's rmse: 3.83022
# [2000]	training's rmse: 3.85149	valid_1's rmse: 3.83024
# Early stopping, best iteration is:
# [1608]	training's rmse: 3.85149	valid_1's rmse: 3.83022
# fold n°9
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85991	valid_1's rmse: 3.7535
# [1000]	training's rmse: 3.85987	valid_1's rmse: 3.75348
# Early stopping, best iteration is:
# [943]	training's rmse: 3.85988	valid_1's rmse: 3.75347
# |  20       | -3.849    |  0.6032   |  0.8323   |  5.754    |  1.491    |  198.1    |  199.8    |
# fold n°0
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84077	valid_1's rmse: 3.9207
# [1000]	training's rmse: 3.84074	valid_1's rmse: 3.92056
# [1500]	training's rmse: 3.84073	valid_1's rmse: 3.92052
# [2000]	training's rmse: 3.84073	valid_1's rmse: 3.92051
# [2500]	training's rmse: 3.84073	valid_1's rmse: 3.9205
# [3000]	training's rmse: 3.84073	valid_1's rmse: 3.9205
# Early stopping, best iteration is:
# [2882]	training's rmse: 3.84073	valid_1's rmse: 3.9205
# fold n°1
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84948	valid_1's rmse: 3.84304
# [1000]	training's rmse: 3.84942	valid_1's rmse: 3.84312
# Early stopping, best iteration is:
# [523]	training's rmse: 3.84948	valid_1's rmse: 3.84304
# fold n°2
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8571	valid_1's rmse: 3.77369
# [1000]	training's rmse: 3.85706	valid_1's rmse: 3.7736
# [1500]	training's rmse: 3.85706	valid_1's rmse: 3.77358
# [2000]	training's rmse: 3.85705	valid_1's rmse: 3.77357
# [2500]	training's rmse: 3.85705	valid_1's rmse: 3.77356
# [3000]	training's rmse: 3.85705	valid_1's rmse: 3.77356
# [3500]	training's rmse: 3.85705	valid_1's rmse: 3.77356
# Early stopping, best iteration is:
# [3168]	training's rmse: 3.85705	valid_1's rmse: 3.77355
# fold n°3
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85048	valid_1's rmse: 3.834
# [1000]	training's rmse: 3.85043	valid_1's rmse: 3.83395
# [1500]	training's rmse: 3.85043	valid_1's rmse: 3.83394
# [2000]	training's rmse: 3.85043	valid_1's rmse: 3.83393
# Early stopping, best iteration is:
# [1983]	training's rmse: 3.85043	valid_1's rmse: 3.83393
# fold n°4
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.86775	valid_1's rmse: 3.67417
# Early stopping, best iteration is:
# [305]	training's rmse: 3.86785	valid_1's rmse: 3.67414
# fold n°5
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84533	valid_1's rmse: 3.88036
# [1000]	training's rmse: 3.84529	valid_1's rmse: 3.88021
# [1500]	training's rmse: 3.84529	valid_1's rmse: 3.88018
# [2000]	training's rmse: 3.84529	valid_1's rmse: 3.88017
# [2500]	training's rmse: 3.84529	valid_1's rmse: 3.88016
# [3000]	training's rmse: 3.84529	valid_1's rmse: 3.88016
# Early stopping, best iteration is:
# [2927]	training's rmse: 3.84529	valid_1's rmse: 3.88016
# fold n°6
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.82872	valid_1's rmse: 4.02521
# Early stopping, best iteration is:
# [152]	training's rmse: 3.82914	valid_1's rmse: 4.02491
# fold n°7
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.83813	valid_1's rmse: 3.94392
# [1000]	training's rmse: 3.83809	valid_1's rmse: 3.94386
# Early stopping, best iteration is:
# [944]	training's rmse: 3.83809	valid_1's rmse: 3.94385
# fold n°8
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8509	valid_1's rmse: 3.83011
# Early stopping, best iteration is:
# [429]	training's rmse: 3.85093	valid_1's rmse: 3.8301
# fold n°9
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85926	valid_1's rmse: 3.75367
# Early stopping, best iteration is:
# [219]	training's rmse: 3.85948	valid_1's rmse: 3.75358
# |  21       | -3.849    |  0.9759   |  0.9331   |  0.7481   |  3.1      |  1.761    |  199.6    |
# fold n°0
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.84132	valid_1's rmse: 3.92186
# [1000]	training's rmse: 3.84124	valid_1's rmse: 3.92181
# Early stopping, best iteration is:
# [861]	training's rmse: 3.84125	valid_1's rmse: 3.92179
# fold n°1
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85017	valid_1's rmse: 3.84307
# [1000]	training's rmse: 3.8501	valid_1's rmse: 3.84291
# [1500]	training's rmse: 3.85009	valid_1's rmse: 3.84287
# [2000]	training's rmse: 3.85009	valid_1's rmse: 3.84286
# Early stopping, best iteration is:
# [1698]	training's rmse: 3.85009	valid_1's rmse: 3.84285
# fold n°2
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85765	valid_1's rmse: 3.77477
# [1000]	training's rmse: 3.85756	valid_1's rmse: 3.77476
# Early stopping, best iteration is:
# [757]	training's rmse: 3.85759	valid_1's rmse: 3.77473
# fold n°3
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85114	valid_1's rmse: 3.83411
# [1000]	training's rmse: 3.85107	valid_1's rmse: 3.83404
# [1500]	training's rmse: 3.85106	valid_1's rmse: 3.83405
# Early stopping, best iteration is:
# [1210]	training's rmse: 3.85106	valid_1's rmse: 3.83403
# fold n°4
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8684	valid_1's rmse: 3.67454
# [1000]	training's rmse: 3.86832	valid_1's rmse: 3.6745
# Early stopping, best iteration is:
# [897]	training's rmse: 3.86833	valid_1's rmse: 3.67448
# fold n°5
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.8459	valid_1's rmse: 3.88127
# [1000]	training's rmse: 3.84582	valid_1's rmse: 3.88122
# [1500]	training's rmse: 3.84581	valid_1's rmse: 3.8812
# [2000]	training's rmse: 3.84581	valid_1's rmse: 3.8812
# [2500]	training's rmse: 3.84581	valid_1's rmse: 3.88119
# Early stopping, best iteration is:
# [2014]	training's rmse: 3.84581	valid_1's rmse: 3.88119
# fold n°6
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.82939	valid_1's rmse: 4.02528
# Early stopping, best iteration is:
# [171]	training's rmse: 3.82978	valid_1's rmse: 4.02516
# fold n°7
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.83871	valid_1's rmse: 3.94497
# [1000]	training's rmse: 3.83864	valid_1's rmse: 3.94472
# [1500]	training's rmse: 3.83864	valid_1's rmse: 3.94467
# [2000]	training's rmse: 3.83864	valid_1's rmse: 3.94461
# Early stopping, best iteration is:
# [1767]	training's rmse: 3.83864	valid_1's rmse: 3.94463
# fold n°8
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85157	valid_1's rmse: 3.83043
# [1000]	training's rmse: 3.8515	valid_1's rmse: 3.83026
# [1500]	training's rmse: 3.85149	valid_1's rmse: 3.83025
# [2000]	training's rmse: 3.85149	valid_1's rmse: 3.83024
# Early stopping, best iteration is:
# [1806]	training's rmse: 3.85149	valid_1's rmse: 3.83022
# fold n°9
# Training until validation scores don't improve for 500 rounds.
# [500]	training's rmse: 3.85996	valid_1's rmse: 3.75351
# [1000]	training's rmse: 3.85988	valid_1's rmse: 3.75346
# Early stopping, best iteration is:
# [764]	training's rmse: 3.8599	valid_1's rmse: 3.75345
# |  22       | -3.849    |  0.452    |  0.3512   |  4.988    |  19.92    |  2.836    |  199.5    |
# =================================================================================================
#
#  Time taken: 0 hours 24 minutes and 38.87 seconds.
# ----------------------------------------------------------------------------------------------------------------------------------
# Final Results
# Maximum  value: -3.848968
# Best  parameters:  {'bagging_fraction': 0.8697868180997999, 'feature_fraction': 0.8462699105559646, 'min_data_in_leaf': 1.1011352436412583, 'num_leaves': 198.3994304170893, 'max_depth': 3.5569471946910265, 'lambda_l1': 1.0290758065145835}
